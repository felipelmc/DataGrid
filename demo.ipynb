# %% [markdown]
# # 🎲 Testing the **DataGrid** module

# %% [markdown]
# Import the class:

# %%
import sys
sys.path.append('src/')

from datagrid import DataGrid

# %% [markdown]
# Instantiate the class:

# %%
datagrid = DataGrid()

# %% [markdown]
# ### `.read_csv(file, sep = ',', encoding = 'utf-8')`

# %% [markdown]
# You can read a `.csv` file into the datagrid object.

# %%
datagrid.read_csv("data/fake_data100.csv")

# %% [markdown]
# ### `.show(start = 0, end = 100)`

# %% [markdown]
# You can also show the range of rows you'd like. By default, the method returns the first 100 rows. If you'd like, you can ask it to print by setting the `prints` parameter to `True`.

# %%
datagrid.show(0, 10, prints = False, returns=True)
# Out:
# [<datagrid.Event at 0x7fc83849ead0>,
#  <datagrid.Event at 0x7fc83849ea70>,
#  <datagrid.Event at 0x7fc83849d0c0>,
#  <datagrid.Event at 0x7fc83849d210>,
#  <datagrid.Event at 0x7fc83849e5c0>,
#  <datagrid.Event at 0x7fc83849d030>,
#  <datagrid.Event at 0x7fc83849e9b0>,
#  <datagrid.Event at 0x7fc83849d2a0>,
#  <datagrid.Event at 0x7fc83849ed40>,
#  <datagrid.Event at 0x7fc83849ed70>,
#  <datagrid.Event at 0x7fc83849ec20>]

# %%
datagrid.show(0, 10, prints = True, returns=False)
# Out:
# 0 Y2U70 2006/05/01 04:19:15 52 ZAEMTRF WXJKOKBNZY70N3TLVGI1ARLDBC8NKKPDDVUX9C1CH72UUHEJN9N14I1ACC384PINKQYGDDAJ3SG7OMEJOPJ1T9GOVME2W4T8O1RFYPRXAQAR
# 1 8DGBJ 2003/05/26 12:45:40 50 YXETLEYPSHN VP582U9GFJY02CJZU2Z6RYK3H7A8Q24MIDZGU2ACM1L91GY5FW35OOVMW6NJA53XGVI2U0QJE7HSUGBABKWFRCY61BHMPIGTL6Z
# 2 0P7BW 2014/02/19 20:05:48 25 CXTYEIS LOBUZPFGTEFN1ULIMRJGIWC1DCYQRIUWHSJT2WDEKOD44WAA5L9JAG3GKITPLRPCQRYAU4YI66T4Y6DMYGJNCEGADJMFZ1UR0SDWRX2LMEFXVXCUBT
# 3 Y43QY 2006/09/21 15:23:47 18 KQOBPGSRKVX 
# 4 FFBE7 2006/12/09 03:53:15 11 LOQFTSPJVYCJQEU 
# 5 X7P9D 2005/04/18 06:02:26 78 D FT2J8G97PP76E2BWXYHUYMBHUPQZZF9R1UFTBSI3E6WHJUAFEY3DF5KXJ1Q1TZR39EEZ2ZKIPK10NVAGM2JK3WEWFZ3SM78Q6J0EFHIRKYEIL62I3RERUBZX4L1TMWNQGUPZTBRFC7NXU0X44A03VZF09F7WJ680RLYFPFIUKGKXC9F2N
# 6 O4SL3 2013/08/31 11:59:40 77 PNJZVFDQJUXPEVEL 8V05E484KGCFAF7RQR0PAZ8WDD1PUQJVPVPMCDETJ6R3AYETY4
# 7 D9WY9 2007/08/29 16:38:41 67 WZXGOO E5A7YC18L1D2E2JKXQK2P0HQIR8FEVC2X7125TKUG2R9NWVY4J52C8IXABILTLJ83YZ8HOQFLVDX5ON7TIJIXM7E6PCKIC3A8E52HXASJQ34HEJMH3GZ90V0YU3UK9GKZ9JTNJ2KGGPUBIE53O7IP162UXOAKT48EPKN8YZPA4EU1NG4P643XMTGCSUL9G6UW3QWWTLYBYMJ
# 8 0PLHU 2010/11/08 21:26:41 47 PXNXBHWORCXONE 34PIA2AB8LDAR4F8B92Z5MKTMTX4XQ4YTKEVGYSPJ8M1ZZVRP7DHHGKEK4IVCUEYJ3BTW46JJV3THLK11J07UR32FJI3N220JRELWF9220ETQUHHM970HX70TMS76UMD4HSZ57OA52IC92MVMYCMJAM6J2M4EIWKSE9Z95PE8GA26E3M5X8U6FZEXEZQ2K9S0I0VCXXP07J9DWJCWZV39VFV9O5TA5R8T3S00QCKS8DMK91YG3PZT5
# 9 LBK31 2010/09/19 10:31:10 37  
# 10 JFE57 2011/05/02 12:06:47 63 LTMQBIY 

# %% [markdown]
# ### `.insert_row(row)`

# %% [markdown]
# You may want to add rows through a dictionary. In the example below, we add a row if an ID which is already in the datagrid. This will update the row.

# %%
new_row = {"id": 1, "owner_id": "ABC123", "creation_date": "2023/10/06 12:00:15", "count": 6, "name": "Item 98", "content": "This is the new content for Item 98"}
datagrid.insert_row(new_row)

# %%
datagrid.show(0, 6, prints=True, returns=False)
# Out:
# 0 Y2U70 2006/05/01 04:19:15 52 ZAEMTRF WXJKOKBNZY70N3TLVGI1ARLDBC8NKKPDDVUX9C1CH72UUHEJN9N14I1ACC384PINKQYGDDAJ3SG7OMEJOPJ1T9GOVME2W4T8O1RFYPRXAQAR
# 1 ABC123 2023/10/06 12:00:15 6 Item 98 This is the new content for Item 98
# 2 0P7BW 2014/02/19 20:05:48 25 CXTYEIS LOBUZPFGTEFN1ULIMRJGIWC1DCYQRIUWHSJT2WDEKOD44WAA5L9JAG3GKITPLRPCQRYAU4YI66T4Y6DMYGJNCEGADJMFZ1UR0SDWRX2LMEFXVXCUBT
# 3 Y43QY 2006/09/21 15:23:47 18 KQOBPGSRKVX 
# 4 FFBE7 2006/12/09 03:53:15 11 LOQFTSPJVYCJQEU 
# 5 X7P9D 2005/04/18 06:02:26 78 D FT2J8G97PP76E2BWXYHUYMBHUPQZZF9R1UFTBSI3E6WHJUAFEY3DF5KXJ1Q1TZR39EEZ2ZKIPK10NVAGM2JK3WEWFZ3SM78Q6J0EFHIRKYEIL62I3RERUBZX4L1TMWNQGUPZTBRFC7NXU0X44A03VZF09F7WJ680RLYFPFIUKGKXC9F2N
# 6 O4SL3 2013/08/31 11:59:40 77 PNJZVFDQJUXPEVEL 8V05E484KGCFAF7RQR0PAZ8WDD1PUQJVPVPMCDETJ6R3AYETY4

# %% [markdown]
# ### `.delete_row(column, value)`

# %% [markdown]
# You can delete rows based on the value of the columns:

# %%
datagrid.delete_row(column="id", value=5)

# %%
datagrid.show(0, 6, prints=True, returns=False)
# Out:
# 0 Y2U70 2006/05/01 04:19:15 52 ZAEMTRF WXJKOKBNZY70N3TLVGI1ARLDBC8NKKPDDVUX9C1CH72UUHEJN9N14I1ACC384PINKQYGDDAJ3SG7OMEJOPJ1T9GOVME2W4T8O1RFYPRXAQAR
# 1 ABC123 2023/10/06 12:00:15 6 Item 98 This is the new content for Item 98
# 2 0P7BW 2014/02/19 20:05:48 25 CXTYEIS LOBUZPFGTEFN1ULIMRJGIWC1DCYQRIUWHSJT2WDEKOD44WAA5L9JAG3GKITPLRPCQRYAU4YI66T4Y6DMYGJNCEGADJMFZ1UR0SDWRX2LMEFXVXCUBT
# 3 Y43QY 2006/09/21 15:23:47 18 KQOBPGSRKVX 
# 4 FFBE7 2006/12/09 03:53:15 11 LOQFTSPJVYCJQEU 
# 6 O4SL3 2013/08/31 11:59:40 77 PNJZVFDQJUXPEVEL 8V05E484KGCFAF7RQR0PAZ8WDD1PUQJVPVPMCDETJ6R3AYETY4
# 7 D9WY9 2007/08/29 16:38:41 67 WZXGOO E5A7YC18L1D2E2JKXQK2P0HQIR8FEVC2X7125TKUG2R9NWVY4J52C8IXABILTLJ83YZ8HOQFLVDX5ON7TIJIXM7E6PCKIC3A8E52HXASJQ34HEJMH3GZ90V0YU3UK9GKZ9JTNJ2KGGPUBIE53O7IP162UXOAKT48EPKN8YZPA4EU1NG4P643XMTGCSUL9G6UW3QWWTLYBYMJ

# %% [markdown]
# Deleting according to position:

# %%
datagrid.delete_row(column="position", value=1)

# %%
datagrid.show(0, 6, prints=True, returns=False)
# Out:
# 0 Y2U70 2006/05/01 04:19:15 52 ZAEMTRF WXJKOKBNZY70N3TLVGI1ARLDBC8NKKPDDVUX9C1CH72UUHEJN9N14I1ACC384PINKQYGDDAJ3SG7OMEJOPJ1T9GOVME2W4T8O1RFYPRXAQAR
# 2 0P7BW 2014/02/19 20:05:48 25 CXTYEIS LOBUZPFGTEFN1ULIMRJGIWC1DCYQRIUWHSJT2WDEKOD44WAA5L9JAG3GKITPLRPCQRYAU4YI66T4Y6DMYGJNCEGADJMFZ1UR0SDWRX2LMEFXVXCUBT
# 3 Y43QY 2006/09/21 15:23:47 18 KQOBPGSRKVX 
# 4 FFBE7 2006/12/09 03:53:15 11 LOQFTSPJVYCJQEU 
# 6 O4SL3 2013/08/31 11:59:40 77 PNJZVFDQJUXPEVEL 8V05E484KGCFAF7RQR0PAZ8WDD1PUQJVPVPMCDETJ6R3AYETY4
# 7 D9WY9 2007/08/29 16:38:41 67 WZXGOO E5A7YC18L1D2E2JKXQK2P0HQIR8FEVC2X7125TKUG2R9NWVY4J52C8IXABILTLJ83YZ8HOQFLVDX5ON7TIJIXM7E6PCKIC3A8E52HXASJQ34HEJMH3GZ90V0YU3UK9GKZ9JTNJ2KGGPUBIE53O7IP162UXOAKT48EPKN8YZPA4EU1NG4P643XMTGCSUL9G6UW3QWWTLYBYMJ
# 8 0PLHU 2010/11/08 21:26:41 47 PXNXBHWORCXONE 34PIA2AB8LDAR4F8B92Z5MKTMTX4XQ4YTKEVGYSPJ8M1ZZVRP7DHHGKEK4IVCUEYJ3BTW46JJV3THLK11J07UR32FJI3N220JRELWF9220ETQUHHM970HX70TMS76UMD4HSZ57OA52IC92MVMYCMJAM6J2M4EIWKSE9Z95PE8GA26E3M5X8U6FZEXEZQ2K9S0I0VCXXP07J9DWJCWZV39VFV9O5TA5R8T3S00QCKS8DMK91YG3PZT5

# %%
datagrid.delete_row(column="position", value=(0, 2))

# %%
datagrid.show(0, 6, prints=True, returns=False)
# Out:
# 4 FFBE7 2006/12/09 03:53:15 11 LOQFTSPJVYCJQEU 
# 6 O4SL3 2013/08/31 11:59:40 77 PNJZVFDQJUXPEVEL 8V05E484KGCFAF7RQR0PAZ8WDD1PUQJVPVPMCDETJ6R3AYETY4
# 7 D9WY9 2007/08/29 16:38:41 67 WZXGOO E5A7YC18L1D2E2JKXQK2P0HQIR8FEVC2X7125TKUG2R9NWVY4J52C8IXABILTLJ83YZ8HOQFLVDX5ON7TIJIXM7E6PCKIC3A8E52HXASJQ34HEJMH3GZ90V0YU3UK9GKZ9JTNJ2KGGPUBIE53O7IP162UXOAKT48EPKN8YZPA4EU1NG4P643XMTGCSUL9G6UW3QWWTLYBYMJ
# 8 0PLHU 2010/11/08 21:26:41 47 PXNXBHWORCXONE 34PIA2AB8LDAR4F8B92Z5MKTMTX4XQ4YTKEVGYSPJ8M1ZZVRP7DHHGKEK4IVCUEYJ3BTW46JJV3THLK11J07UR32FJI3N220JRELWF9220ETQUHHM970HX70TMS76UMD4HSZ57OA52IC92MVMYCMJAM6J2M4EIWKSE9Z95PE8GA26E3M5X8U6FZEXEZQ2K9S0I0VCXXP07J9DWJCWZV39VFV9O5TA5R8T3S00QCKS8DMK91YG3PZT5
# 9 LBK31 2010/09/19 10:31:10 37  
# 10 JFE57 2011/05/02 12:06:47 63 LTMQBIY 
# 11 CC0I9 2008/05/12 20:48:59 21 B FVH2LA98687JFS2OT7LU2F3DR4Q

# %% [markdown]
# Searching and deleting a range of count values:

# %%
datagrid.search(column="count", value=(20, 21))
# Out:
# [<datagrid.Event at 0x7fc83849ea10>,
#  <datagrid.Event at 0x7fc83849d450>,
#  <datagrid.Event at 0x7fc83849dc90>,
#  <datagrid.Event at 0x7fc83849d360>]

# %%
datagrid.delete_row(column="count", value=(20, 21))

# %%
datagrid.search(column="count", value=(20, 21))

# %% [markdown]
# Searching and deleting a range of name values:

# %%
datagrid.search("name", "A")
# Out:
# [<datagrid.Event at 0x7fc83849dd80>,
#  <datagrid.Event at 0x7fc83849e5f0>,
#  <datagrid.Event at 0x7fc83849ee00>,
#  <datagrid.Event at 0x7fc83849e680>,
#  <datagrid.Event at 0x7fc83849e7d0>,
#  <datagrid.Event at 0x7fc83849eda0>,
#  <datagrid.Event at 0x7fc83849d1b0>,
#  <datagrid.Event at 0x7fc83849e7a0>,
#  <datagrid.Event at 0x7fc83849d420>,
#  <datagrid.Event at 0x7fc83849ea40>,
#  <datagrid.Event at 0x7fc83849ee30>,
#  <datagrid.Event at 0x7fc83849d1e0>,
#  <datagrid.Event at 0x7fc83849e3b0>,
#  <datagrid.Event at 0x7fc83849e950>,
#  <datagrid.Event at 0x7fc83849d780>,
#  <datagrid.Event at 0x7fc83849d0f0>,
#  <datagrid.Event at 0x7fc83849cdf0>,
#  <datagrid.Event at 0x7fc83849d390>,
#  <datagrid.Event at 0x7fc83849e740>,
#  <datagrid.Event at 0x7fc83849ee90>,
#  <datagrid.Event at 0x7fc83849ef80>,
#  <datagrid.Event at 0x7fc83849d120>,
#  <datagrid.Event at 0x7fc83849ec50>,
#  <datagrid.Event at 0x7fc83849ed10>,
#  <datagrid.Event at 0x7fc83849ebc0>,
#  <datagrid.Event at 0x7fc83849e890>,
#  <datagrid.Event at 0x7fc83849e980>,
#  <datagrid.Event at 0x7fc83849e8c0>,
#  <datagrid.Event at 0x7fc83849dcc0>,
#  <datagrid.Event at 0x7fc83849e9e0>,
#  <datagrid.Event at 0x7fc83849d180>,
#  <datagrid.Event at 0x7fc83849eb60>]

# %%
datagrid.delete_row("name", "A")

# %%
datagrid.search("name", "A")

# %% [markdown]
# Searching and deleting a range of content values:

# %%
datagrid.search("content", "XS")
# Out:
# [<datagrid.Event at 0x7fc83849e5c0>,
#  <datagrid.Event at 0x7fc83849ed70>,
#  <datagrid.Event at 0x7fc83849ef50>,
#  <datagrid.Event at 0x7fc83849d7b0>,
#  <datagrid.Event at 0x7fc83849dc00>,
#  <datagrid.Event at 0x7fc83849cd60>,
#  <datagrid.Event at 0x7fc83849e710>,
#  <datagrid.Event at 0x7fc83849ee60>,
#  <datagrid.Event at 0x7fc83849dd20>]

# %%
datagrid.delete_row("content", "XS")

# %%
datagrid.search("content", "XS")

# %% [markdown]
# ### `.search(column, value)`

# %%
datagrid.search(column="id", value=5)

# %%
datagrid.search(column="owner_id", value="ZXR2E")

# %%
datagrid.search("creation_date", ("2007/03/22 00:00:00", "2007/06/23 00:00:00"))

# %%
datagrid.search(column="count", value=(18, 19))

# %%
datagrid.search("name", "AL")

# %%
datagrid.search("content", "XC")
# Out:
# [<datagrid.Event at 0x7fc83849e3e0>,
#  <datagrid.Event at 0x7fc83849e620>,
#  <datagrid.Event at 0x7fc83849d2d0>,
#  <datagrid.Event at 0x7fc83849d750>,
#  <datagrid.Event at 0x7fc83849d720>,
#  <datagrid.Event at 0x7fc83849eec0>]

# %% [markdown]
# ### `.sort(column, direction = 'asc')`

# %%
datagrid.sort(column="id", direction="desc")

# %% [markdown]
# Now the `show()` method will show the sorted datagrid:

# %%
datagrid.show(0, 10, prints=True, returns=False)
# Out:
# 97 Q6QIV 2005/08/27 11:10:15 44 BEKWHEDU 9WBOBVP13KLY6QXADERS7PZXML4OJHSCFSTA7LOFQLQNKPK26UXLUSP3OMAR2PFL1GMDVTV3C1LTIINE0UQ40W87TRXPHMM8SVKLA1V080BI9M4EAI2XUAEL2GC12QEVJ43Z60MOH5WS27HPS3OB2R7VNJ8T4N6GOT24IAEP36MJSM56O7BFC776LYO7XUR69T1O2AGE3T7T9ITECRFQXPV0IFSAO8CB0V0EOJM49PB8
# 95 WQOPA 2005/08/07 01:04:22 60 KGBN 
# 91 5TGG2 2001/05/19 22:57:08 37 LJ 

# 6 O4SL3 2013/08/31 11:59:40 77 PNJZVFDQJUXPEVEL 8V05E484KGCFAF7RQR0PAZ8WDD1PUQJVPVPMCDETJ6R3AYETY4

# %%
datagrid.show(0, 5, prints=False, returns=True)
# Out:
# [<datagrid.Event at 0x7fc83849e590>,
#  <datagrid.Event at 0x7fc83849e3e0>,
#  <datagrid.Event at 0x7fc83849d2d0>,
#  <datagrid.Event at 0x7fc83849e6e0>,
#  <datagrid.Event at 0x7fc83849e620>,
#  <datagrid.Event at 0x7fc83849e9b0>]

# %% [markdown]
# ### `.select_count(i, j)`

# %% [markdown]
# This method returns the entries between $i$ and $j$, $[i, j]$, considering the `count` feature sorted in ascending order.

# %%
# to use median-of-medians
datagrid.select_count(0, 10, how="median-of-medians")
# Out:
# [<datagrid.Event at 0x7fc83849ce20>,
#  <datagrid.Event at 0x7fc83849e650>,
#  <datagrid.Event at 0x7fc83849e920>,
#  <datagrid.Event at 0x7fc83849d000>,
#  <datagrid.Event at 0x7fc83849eb00>,
#  <datagrid.Event at 0x7fc83849e830>,
#  <datagrid.Event at 0x7fc83849dd50>,
#  <datagrid.Event at 0x7fc83849d300>,
#  <datagrid.Event at 0x7fc83849eb90>,
#  <datagrid.Event at 0x7fc83849d750>,
#  <datagrid.Event at 0x7fc83849e800>]

# %%
# to use quickselect
datagrid.select_count(0, 10, how = "quickselect")
# Out:
# [<datagrid.Event at 0x7fc83849ce20>,
#  <datagrid.Event at 0x7fc83849e650>,
#  <datagrid.Event at 0x7fc83849d000>,
#  <datagrid.Event at 0x7fc83849e920>,
#  <datagrid.Event at 0x7fc83849eb00>,
#  <datagrid.Event at 0x7fc83849e830>,
#  <datagrid.Event at 0x7fc83849d300>,
#  <datagrid.Event at 0x7fc83849dd50>,
#  <datagrid.Event at 0x7fc83849eb90>,
#  <datagrid.Event at 0x7fc83849d750>,
#  <datagrid.Event at 0x7fc83849e800>]

# %%
# to use heapsort
datagrid.select_count(0, 10, how="heapsort")
# Out:
# [<datagrid.Event at 0x7fc83849ce20>,
#  <datagrid.Event at 0x7fc83849e650>,
#  <datagrid.Event at 0x7fc83849e920>,
#  <datagrid.Event at 0x7fc83849d000>,
#  <datagrid.Event at 0x7fc83849eb00>,
#  <datagrid.Event at 0x7fc83849e830>,
#  <datagrid.Event at 0x7fc83849d300>,
#  <datagrid.Event at 0x7fc83849dd50>,
#  <datagrid.Event at 0x7fc83849eb90>,
#  <datagrid.Event at 0x7fc83849d750>,
#  <datagrid.Event at 0x7fc83849e800>]

# %% [markdown]
# Also, the `select_count()` method does not change the internal state of the data structure, which can be confirmed by the `.show()` method. It shows the result of the last-applied sorting, before the `select_count()`.

# %%
datagrid.show(0, 20, prints=True, returns=False)
# Out:
# 66 BE3E8 2015/10/23 13:29:31 97 RSELTCOIOFSKXQKYW 3F0Z617X5Y75WK72S8DB1PDQPGTUBVBROQAYS0V5PFIBMRB87K9NZLGKQDLAIEEDBBPKVQB0K7QOB9TRZMGDJSIZS8P79GHW6DU8QS68JT
# 95 WQOPA 2005/08/07 01:04:22 60 KGBN 
# 71 BKP3V 2010/03/31 11:04:14 58 ITIU GDMFX3YTJBW7PUBVDLW0LTKWS8HGJCLNV2QZCUU3JYY9CQGXH18IWEH25QN5995T8Z0ZMPSGTAD3YNGKDH2SAOPAJ9P6AZT51ZQ6WCQNUX65HLY
# 23 LK6SQ 2001/02/27 05:21:13 56 GHTTTVZX 5T1BJDS7M6OR0VBD86A4FTEYSXKVTXBEU
# 74 8JD5N 2009/05/27 16:51:18 54 D 
# 89 H5JPW 2002/10/29 03:59:07 54 JZDOOTKBZCD 
# 75 GMHFG 2004/09/14 11:07:04 51 UPKPHREEHKGTTRFCG 

# %% [markdown]
# ---

# %% [markdown]
# # 🔎 Testing the **Open Addressing** nature of our **HashTable**

# %%
datagrid2 = DataGrid()

# %% [markdown]
# Let's insert some values into the hashtable:

# %%
ids = [1, 2, 3, 4, 5, 11, 21]

for id in ids:
    row = {}
    row["id"] = id
    row["owner_id"] = "ABC123"
    row["creation_date"] = "2023/10/06 12:00:15"
    row["count"] = id
    row["name"] = "Item " + str(id)
    row["content"] = "This is the content for Item " + str(id)
    datagrid2.insert_row(row)

# %%
datagrid2.show(0, 10)
# Out:
# /home/felipe/Área de Trabalho/datagrid/src/datagrid.py:81: UserWarning: `end` is greater than the size of the datagrid, setting `end` to the datagrid size
#   warnings.warn("`end` is greater than the size of the datagrid, setting `end` to the datagrid size")
# [<datagrid.Event at 0x7fc83849fe80>,
#  <datagrid.Event at 0x7fc83849f730>,
#  <datagrid.Event at 0x7fc83849fdf0>,
#  <datagrid.Event at 0x7fc83849fa90>,
#  <datagrid.Event at 0x7fc83849fcd0>,
#  <datagrid.Event at 0x7fc838300250>,
#  <datagrid.Event at 0x7fc838300280>]

# %% [markdown]
# If we search for the `id = 1`, we will see:

# %%
datagrid2.search(column="id", value=1)

# %% [markdown]
# Same for `id = 11`. Remember that our hash function is `h(x) = x % 10`, so they are both mapped to the same position.

# %%
datagrid2.search(column="id", value=11)

# %% [markdown]
# Let's delete the entry with `id = 1`:

# %%
datagrid2.delete_row(column="id", value=1)

# %%
datagrid2.search(column="id", value=1)

# %% [markdown]
# If our implementation is right, we should still be able to find the entry with `id = 11`:

# %%
datagrid2.search(column="id", value=11)

# %% [markdown]
# It seems to work just fine. Let's try to delete the entry with `id = 11`:

# %%
datagrid2.delete_row(column="id", value=11)

# %% [markdown]
# If we search for it again, we should receive nothing:

# %%
datagrid2.search(column="id", value=11)

# %% [markdown]
# Also note that our `.show()` method shows us each row, removing the deleted entries.

# %%
datagrid2.show(0, 10)
# Out:
# [<datagrid.Event at 0x7fc83849f730>,
#  <datagrid.Event at 0x7fc83849fdf0>,
#  <datagrid.Event at 0x7fc83849fa90>,
#  <datagrid.Event at 0x7fc83849fcd0>,
#  <datagrid.Event at 0x7fc838300280>]

# %% [markdown]
# Note that we also have the entry with `id = 21`, which is mapped to the same position as `id = 1` and `id = 11`. Let's try to find it:

# %%
datagrid2.search(column="id", value=21)
